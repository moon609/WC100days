# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %% [markdown]
# ### 對 API 的承載是由 documents 清單所組成，其為包含 id 和 text 屬性的元組。 text 屬性會儲存要分析的文字，而 id 可以是任何值。
#
# #### r.text
# * 以r來儲存想要爬資料的目標網址
# * r.text是發送請求的動作
# * 將所有的資料以混合的一組str呈現，資料不容易識別
#
# #### json.loads(r.text)
# * json以清楚的方式呈現資料，以list的方式將一組組資料分別呈現。
# * 將字串轉換為字典

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"12751628788","type":"PushEvent","actor":{"id":31752426,"login":"Habist","display_login":"Habist","gravatar_id":"","url":"https://api.github.com/users/Habist","avatar_url":"https://avatars.githubusercontent.com/u/31752426?"},"repo":{"id":247237616,"name":"Habist/TwitterFilterAPI-Java","url":"https://api.github.com/repos/Habist/TwitterFilterAPI-Java"},"payload":{"push_id":5292949379,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"62b4bbe5d87baccec150c8e5a01737afcee87dd8","before":"5c6562832bc33093bab7c1f2bf300fa883d486ac","commits":[{"sha":"62b4bbe5d87baccec150c8e5a01737afcee87dd8","author":{"email":"liasn@naver.com","name":"Habist"},"message":"parameters properties 추가","distinct":true,"url":"https://api.github.com/repos/Habist/TwitterFilterAPI-Java/commits/62b4bbe5d87baccec150c8e5a01737afcee87dd8"}]},"public":true,"created_at":"2020-06-27T12:07:41Z"},{"id":"12751628786","type":"PushEvent","actor":{"id":58574743,"login":"tonymackay","display_login":"tonymackay","gravatar_id":"","url":"https://api.github.com/users/tonymackay","avatar_url":"https://avatars.githubusercontent.com/u/58574743?"},"repo":{"id":275267595,"name":"tonymackay/docker-zopflipng","url":"https://api.github.com/repos/tonymackay/docker-zopflipng"},"payload":{"push_id":5292949378,"size":3,"distinct_size":3,"ref":"refs/heads/master","head":"02f8e5ce3aa4197c8d8a9f2c2055618d8785af40","before":"7d7d9721140ea5951a4aa0f7d9254b9aba1ab92f","commits":[{"sha":"a9c6ed5309664135eae63ee2dff64f6d6ac92bab","author":{"email":"tony@viewmodel.net","name":"Tony Mackay"},"message":"Add Dockerfile","distinct":true,"url":"https://api.github.com/repos/tonymackay/docker-zopflipng/commits/a9c6ed5309664135eae63ee2dff64f6d6ac92bab"},{"sha":"a87a81bdff8dce6e26a4e2e9a8d382edb8fd877a","author":{"email":"tony@viewmodel.net","name":"Tony Mackay"},"message":"Add build script","distinct":true,"url":"https://api.github.com/repos/tonymackay/docker-zopflipng/commits/a87a81bdff8dce6e26a4e2e9a8d382edb8fd877a"},{"sha":"02f8e5ce3aa4197c8d8a9f2c2055618d8785af40","author":{"email":"tony@viewmodel.net","name":"Tony Mackay"},"message":"docs: Add build and usage instructions","distinct":true,"url":"https://api.github.com/repos/tonymackay/docker-zopflipng/commits/02f8e5ce3aa4197c8d8a9f2c2055618d8785af40"}]},"public":true,"created_at":"2020-06-27T12:07:41Z"},{"id":"12751628787","type":"IssuesEvent","actor":{"id":2148318,"login":"SeanKilleen","display_login":"SeanKilleen","gravatar_id":"","url":"https://api.github.com/users/SeanKilleen","avatar_url":"https://avatars.githubusercontent.com/u/2148318?"},"repo":{"id":50743570,"name":"nunit/docs","url":"https://api.github.com/repos/nunit/docs"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/nunit/docs/issues/427","repository_url":"https://api.github.com/repos/nunit/docs","labels_url":"https://api.github.com/repos/nunit/docs/issues/427/labels{/name}","comments_url":"https://api.github.com/repos/nunit/docs/issues/427/comments","events_url":"https://api.github.com/repos/nunit/docs/issues/427/events","html_url":"https://github.com/nunit/docs/issues/427","id":646669149,"node_id":"MDU6SXNzdWU2NDY2NjkxNDk=","number":427,"title":"Future consideration: Snippets in docfx","user":{"login":"SeanKilleen","id":2148318,"node_id":"MDQ6VXNlcjIxNDgzMTg=","avatar_url":"https://avatars0.githubusercontent.com/u/2148318?v=4","gravatar_id":"","url":"https://api.github.com/users/SeanKilleen","html_url":"https://github.com/SeanKilleen","followers_url":"https://api.github.com/users/SeanKilleen/followers","following_url":"https://api.github.com/users/SeanKilleen/following{/other_user}","gists_url":"https://api.github.com/users/SeanKilleen/gists{/gist_id}","starred_url":"https://api.github.com/users/SeanKilleen/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/SeanKilleen/subscriptions","organizations_url":"https://api.github.com/users/SeanKilleen/orgs","repos_url":"https://api.github.com/users/SeanKilleen/repos","events_u ...

# %%
type(r.text)
# Out:
# str

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '12751628788',
#   'type': 'PushEvent',
#   'actor': {'id': 31752426,
#    'login': 'Habist',
#    'display_login': 'Habist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Habist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31752426?'},
#   'repo': {'id': 247237616,
#    'name': 'Habist/TwitterFilterAPI-Java',
#    'url': 'https://api.github.com/repos/Habist/TwitterFilterAPI-Java'},
#   'payload': {'push_id': 5292949379,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '62b4bbe5d87baccec150c8e5a01737afcee87dd8',
#    'before': '5c6562832bc33093bab7c1f2bf300fa883d486ac',
#    'commits': [{'sha': '62b4bbe5d87baccec150c8e5a01737afcee87dd8',
#      'author': {'email': 'liasn@naver.com', 'name': 'Habist'},
#      'message': 'parameters properties 추가',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Habist/TwitterFilterAPI-Java/commits/62b4bbe5d87baccec150c8e5a01737afcee87dd8'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628786',
#   'type': 'PushEvent',
#   'actor': {'id': 58574743,
#    'login': 'tonymackay',
#    'display_login': 'tonymackay',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tonymackay',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58574743?'},
#   'repo': {'id': 275267595,
#    'name': 'tonymackay/docker-zopflipng',
#    'url': 'https://api.github.com/repos/tonymackay/docker-zopflipng'},
#   'payload': {'push_id': 5292949378,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': '02f8e5ce3aa4197c8d8a9f2c2055618d8785af40',
#    'before': '7d7d9721140ea5951a4aa0f7d9254b9aba1ab92f',
#    'commits': [{'sha': 'a9c6ed5309664135eae63ee2dff64f6d6ac92bab',
#      'author': {'email': 'tony@viewmodel.net', 'name': 'Tony Mackay'},
#      'message': 'Add Dockerfile',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tonymackay/docker-zopflipng/commits/a9c6ed5309664135eae63ee2dff64f6d6ac92bab'},
#     {'sha': 'a87a81bdff8dce6e26a4e2e9a8d382edb8fd877a',
#      'author': {'email': 'tony@viewmodel.net', 'name': 'Tony Mackay'},
#      'message': 'Add build script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tonymackay/docker-zopflipng/commits/a87a81bdff8dce6e26a4e2e9a8d382edb8fd877a'},
#     {'sha': '02f8e5ce3aa4197c8d8a9f2c2055618d8785af40',
#      'author': {'email': 'tony@viewmodel.net', 'name': 'Tony Mackay'},
#      'message': 'docs: Add build and usage instructions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tonymackay/docker-zopflipng/commits/02f8e5ce3aa4197c8d8a9f2c2055618d8785af40'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628787',
#   'type': 'IssuesEvent',
#   'actor': {'id': 2148318,
#    'login': 'SeanKilleen',
#    'display_login': 'SeanKilleen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SeanKilleen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2148318?'},
#   'repo': {'id': 50743570,
#    'name': 'nunit/docs',
#    'url': 'https://api.github.com/repos/nunit/docs'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/nunit/docs/issues/427',
#     'repository_url': 'https://api.github.com/repos/nunit/docs',
#     'labels_url': 'https://api.github.com/repos/nunit/docs/issues/427/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/nunit/docs/issues/427/comments',
#     'events_url': 'https://api.github.com/repos/nunit/docs/issues/427/events',
#     'html_url': 'https://github.com/nunit/docs/issues/427',
#     'id': 646669149,
#     'node_id': 'MDU6SXNzdWU2NDY2NjkxNDk=',
#     'number': 427,
#     'title': 'Future consideration: Snippets in docfx',
#     'user': {'login': 'SeanKilleen',
#      'id': 2148318,
#      'node_id': 'MDQ6VXNlcjIxNDgzMTg=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/2148318?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/SeanKilleen',
#      'html_url': 'https://github.com/SeanKilleen',
#      'followers_url': 'https://api.github.com/users/SeanKilleen/followers',
#      'following_url': 'https://api.github.com/users/SeanKilleen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/SeanKilleen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/SeanKilleen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/SeanKilleen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/SeanKilleen/orgs',
#      'repos_url': 'https://api.github.com/users/SeanKilleen/repos',
#      'events_url': 'https://api.github.com/users/SeanKilleen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/SeanKilleen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-06-27T12:07:41Z',
#     'updated_at': '2020-06-27T12:07:41Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'body': "Not sure this is possible, but while linting hundreds of files, I wished that it was. :) \r\n\r\nSeveral areas in the docs are repeated -- for example, some of the text in the notes for various constraints.\r\n\r\nFor consistency etc, I wonder if it's possible to do includes within docfx so that content that changes can be updated. I believe this is likely possible. \r\n\r\nIf it is, we can find the similar text and then extract the parts that are the exact same.\r\n\r\n<!-- \r\nThis repository is for issues with NUnit documentation.\r\n - If you have an issue with the test framework, go to: https://github.com/nunit/nunit/issues/new\r\n - If you have an issue with the console runner, go to: https://github.com/nunit/nunit-console/issues/new\r\n - If you have an issue with the VSTest adapter, go to: https://github.com/nunit/nunit3-vs-adapter/issues/new\r\n - If you have an issue with another component, go to: https://github.com/nunit#org-repositories\r\n-->\r\n"}},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z',
#   'org': {'id': 2678858,
#    'login': 'nunit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nunit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2678858?'}},
#  {'id': '12751628783',
#   'type': 'PushEvent',
#   'actor': {'id': 550823,
#    'login': 'cnotin',
#    'display_login': 'cnotin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cnotin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/550823?'},
#   'repo': {'id': 269636790,
#    'name': 'cnotin/atomic-red-team',
#    'url': 'https://api.github.com/repos/cnotin/atomic-red-team'},
#   'payload': {'push_id': 5292949376,
#    'size': 23,
#    'distinct_size': 23,
#    'ref': 'refs/heads/patch-3',
#    'head': '82a3e97880390484cce91a4077c9a06538e37811',
#    'before': '3436be144532aea11670d08592b4147eb68c2999',
#    'commits': [{'sha': '96bf275a887c414b63119f7fbf23c1e8db4d3334',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'adding password spray atomic',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/96bf275a887c414b63119f7fbf23c1e8db4d3334'},
#     {'sha': 'd4a0d3fed1cae70c74d1c1b1bd98fe665b07570c',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'fix password variable',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/d4a0d3fed1cae70c74d1c1b1bd98fe665b07570c'},
#     {'sha': '86549295ad8ecba65b14dbc14fd48ad3ec61002c',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'password as input arg',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/86549295ad8ecba65b14dbc14fd48ad3ec61002c'},
#     {'sha': 'a084ff4ae60a435e48cc8776b7587973a7ee595d',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'some cleanup',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/a084ff4ae60a435e48cc8776b7587973a7ee595d'},
#     {'sha': 'e4c0db9a20adc174aed2c4b9ea438aef4d012bca',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'print status .',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/e4c0db9a20adc174aed2c4b9ea438aef4d012bca'},
#     {'sha': '3466f287d2d9b91def6d195e9090631bb06745e4',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'print status .',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/3466f287d2d9b91def6d195e9090631bb06745e4'},
#     {'sha': 'eedfdee5ffc57eaa989929a7ed3f9db61ade6a62',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'print status .',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/eedfdee5ffc57eaa989929a7ed3f9db61ade6a62'},
#     {'sha': 'f5c6f9076cbc65b74e9de7608cd681456826915e',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'fix typo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/f5c6f9076cbc65b74e9de7608cd681456826915e'},
#     {'sha': 'f4fa336bf77a1d896bf13645a2252926f91fcb74',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'parse users script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/f4fa336bf77a1d896bf13645a2252926f91fcb74'},
#     {'sha': '6894cf41ece408d057e73217da6f851abdbae294',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'remove second echo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/6894cf41ece408d057e73217da6f851abdbae294'},
#     {'sha': '7e13ef98af8a3ddf40d71c9c5828ba27152d5b5c',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'link to blog',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/7e13ef98af8a3ddf40d71c9c5828ba27152d5b5c'},
#     {'sha': '608337f3e820ac05eadef3a03210b960a57a84dc',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'link to blog',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/608337f3e820ac05eadef3a03210b960a57a84dc'},
#     {'sha': 'cc80af8eda2152bccb67f07ced162ec1acd0e971',
#      'author': {'email': 'clr2of8@gmail.com', 'name': 'clr2of8'},
#      'message': 'typo fix',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/cc80af8eda2152bccb67f07ced162ec1acd0e971'},
#     {'sha': 'e0d9f79ea8663179e8589a4abbd43fc55b805613',
#      'author': {'email': 'clement@notin.org', 'name': 'Clément Notin'},
#      'message': 'T1003.003: create empty folder for ntdsutil output and add cleanup command (#1089)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/e0d9f79ea8663179e8589a4abbd43fc55b805613'},
#     {'sha': 'ee6524f61af3081857f0041095a91ed2f55b7329',
#      'author': {'email': 'email',
#       'name': 'CircleCI Atomic Red Team doc generator'},
#      'message': 'Generate docs from job=validate_atomics_generate_docs branch=master',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/ee6524f61af3081857f0041095a91ed2f55b7329'},
#     {'sha': '968a3122ac51c471d3b2cc918053613a626968dc',
#      'author': {'email': 'code@0x6c.dev', 'name': 'Hare Sudhan Muthusamy'},
#      'message': 'Pre Requisites added for T1069.002 (#1090)\n\n* Fixed execution issue and added cleanup command\r\n\r\n* Cleanup command added\r\n\r\n* Added cleanup command\r\n\r\n* CheckPreReqs added\r\n\r\n* GetPreReqs added\r\n\r\n* Minor bug fix\r\n\r\n* Update T1069.002.yaml\r\n\r\n* Description change\r\n\r\n* Dependencies change.\r\n\r\nCo-authored-by: Carrie Roberts <clr2of8@gmail.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/968a3122ac51c471d3b2cc918053613a626968dc'},
#     {'sha': '3066499851c90b91bee95117303eeb48e5e7ba8a',
#      'author': {'email': 'email',
#       'name': 'CircleCI Atomic Red Team doc generator'},
#      'message': 'Generate docs from job=validate_atomics_generate_docs branch=master',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/3066499851c90b91bee95117303eeb48e5e7ba8a'},
#     {'sha': 'bdb98ff77b9b36477c85e97550b209569e06a7f5',
#      'author': {'email': 'clement@notin.org', 'name': 'Clément Notin'},
#      'message': 'T1053.005: in remote schtasks, we need username and password for authentication (#1093)\n\n/RU and /RP are credentials for "runas" when running the task, not for remote auth when creating it\r\n\r\nCo-authored-by: Carrie Roberts <clr2of8@gmail.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/bdb98ff77b9b36477c85e97550b209569e06a7f5'},
#     {'sha': '01f44d4333704ce038fe430e108adc130384fdda',
#      'author': {'email': 'email',
#       'name': 'CircleCI Atomic Red Team doc generator'},
#      'message': 'Generate docs from job=validate_atomics_generate_docs branch=master',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/01f44d4333704ce038fe430e108adc130384fdda'},
#     {'sha': '43fed8bcc11db0662391a5cb63b125c8228b92d2',
#      'author': {'email': '60448025+mgraeber-rc@users.noreply.github.com',
#       'name': 'Matt Graeber'},
#      'message': "Merge branch 'master' into password-spray",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cnotin/atomic-red-team/commits/43fed8bcc11db0662391a5cb63b125c8228b92d2'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628781',
#   'type': 'PushEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 183051410,
#    'name': 'direwolf-github/my-app',
#    'url': 'https://api.github.com/repos/direwolf-github/my-app'},
#   'payload': {'push_id': 5292949372,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/branch-75e59746',
#    'head': '059c2599783ce737258067047447b6e73f23a207',
#    'before': '97b657afdf54d3b3ccbcb094fc803fee1c0e5821',
#    'commits': [{'sha': '059c2599783ce737258067047447b6e73f23a207',
#      'author': {'email': 'heroku-lifecycle+direwolf-github@salesforce.com',
#       'name': 'direwolf-github'},
#      'message': 'add readme.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/direwolf-github/my-app/commits/059c2599783ce737258067047447b6e73f23a207'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628771',
#   'type': 'PushEvent',
#   'actor': {'id': 19759888,
#    'login': 'fitsumcs',
#    'display_login': 'fitsumcs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fitsumcs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19759888?'},
#   'repo': {'id': 274656340,
#    'name': 'fitsumcs/Tools',
#    'url': 'https://api.github.com/repos/fitsumcs/Tools'},
#   'payload': {'push_id': 5292949361,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '10f98ecfeb0688056c6e5a512810caa9cc767e73',
#    'before': '3c889503d19742b126dd0ac6faa26f946cabc17c',
#    'commits': [{'sha': '10f98ecfeb0688056c6e5a512810caa9cc767e73',
#      'author': {'email': 'fitsumcs@gmail.com', 'name': 'Fitsum Alemu'},
#      'message': 'Adding youtibe info app UI',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fitsumcs/Tools/commits/10f98ecfeb0688056c6e5a512810caa9cc767e73'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628772',
#   'type': 'IssuesEvent',
#   'actor': {'id': 8954363,
#    'login': 'zteater',
#    'display_login': 'zteater',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zteater',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8954363?'},
#   'repo': {'id': 230709034,
#    'name': 'whelk-io/hy-phen-a-tion',
#    'url': 'https://api.github.com/repos/whelk-io/hy-phen-a-tion'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/whelk-io/hy-phen-a-tion/issues/28',
#     'repository_url': 'https://api.github.com/repos/whelk-io/hy-phen-a-tion',
#     'labels_url': 'https://api.github.com/repos/whelk-io/hy-phen-a-tion/issues/28/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/whelk-io/hy-phen-a-tion/issues/28/comments',
#     'events_url': 'https://api.github.com/repos/whelk-io/hy-phen-a-tion/issues/28/events',
#     'html_url': 'https://github.com/whelk-io/hy-phen-a-tion/issues/28',
#     'id': 646669148,
#     'node_id': 'MDU6SXNzdWU2NDY2NjkxNDg=',
#     'number': 28,
#     'title': 'Warning on deprecated on API at build',
#     'user': {'login': 'zteater',
#      'id': 8954363,
#      'node_id': 'MDQ6VXNlcjg5NTQzNjM=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/8954363?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zteater',
#      'html_url': 'https://github.com/zteater',
#      'followers_url': 'https://api.github.com/users/zteater/followers',
#      'following_url': 'https://api.github.com/users/zteater/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zteater/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zteater/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zteater/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zteater/orgs',
#      'repos_url': 'https://api.github.com/users/zteater/repos',
#      'events_url': 'https://api.github.com/users/zteater/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zteater/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-06-27T12:07:41Z',
#     'updated_at': '2020-06-27T12:07:41Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '```\r\n[WARNING] /Users/zteater/dev/workspace-whelk/hy-phen-a-tion/src/test/java/io/whelk/hy/phen/HyphenatorTest.java: /Users/zteater/dev/workspace-whelk/hy-phen-a-tion/src/test/java/io/whelk/hy/phen/HyphenatorTest.java uses or overrides a deprecated API.\r\n[WARNING] /Users/zteater/dev/workspace-whelk/hy-phen-a-tion/src/test/java/io/whelk/hy/phen/HyphenatorTest.java: Recompile with -Xlint:deprecation for details.\r\n```'}},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z',
#   'org': {'id': 59290646,
#    'login': 'whelk-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/whelk-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59290646?'}},
#  {'id': '12751628769',
#   'type': 'CreateEvent',
#   'actor': {'id': 13203,
#    'login': 'koic',
#    'display_login': 'koic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/koic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13203?'},
#   'repo': {'id': 68358055,
#    'name': 'koic/rubocop',
#    'url': 'https://api.github.com/repos/koic/rubocop'},
#   'payload': {'ref': 'update_example_for_style_multiline_block_chain',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A Ruby static code analyzer, based on the community Ruby style guide.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628767',
#   'type': 'WatchEvent',
#   'actor': {'id': 40893821,
#    'login': 'NoPantsCrash',
#    'display_login': 'NoPantsCrash',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NoPantsCrash',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40893821?'},
#   'repo': {'id': 216587152,
#    'name': 'chiphuyen/python-is-cool',
#    'url': 'https://api.github.com/repos/chiphuyen/python-is-cool'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628765',
#   'type': 'CreateEvent',
#   'actor': {'id': 34137966,
#    'login': 'GenaGorin',
#    'display_login': 'GenaGorin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GenaGorin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34137966?'},
#   'repo': {'id': 275364378,
#    'name': 'GenaGorin/policegrammApp',
#    'url': 'https://api.github.com/repos/GenaGorin/policegrammApp'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'full andriod',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628757',
#   'type': 'CreateEvent',
#   'actor': {'id': 16361735,
#    'login': 'irfanmaulana126',
#    'display_login': 'irfanmaulana126',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/irfanmaulana126',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16361735?'},
#   'repo': {'id': 275364184,
#    'name': 'irfanmaulana126/frist_golang',
#    'url': 'https://api.github.com/repos/irfanmaulana126/frist_golang'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628758',
#   'type': 'CreateEvent',
#   'actor': {'id': 66840235,
#    'login': 'Anastasia-Rybak-2044',
#    'display_login': 'Anastasia-Rybak-2044',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Anastasia-Rybak-2044',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66840235?'},
#   'repo': {'id': 275364377,
#    'name': 'Anastasia-Rybak-2044/NeuroStartUp-Anastasia-Rybak',
#    'url': 'https://api.github.com/repos/Anastasia-Rybak-2044/NeuroStartUp-Anastasia-Rybak'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628754',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 126305625,
#    'name': 'zhlooking/react-ssr-redux',
#    'url': 'https://api.github.com/repos/zhlooking/react-ssr-redux'},
#   'payload': {'action': 'opened',
#    'number': 4,
#    'pull_request': {'url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/4',
#     'id': 440902216,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDQwOTAyMjE2',
#     'html_url': 'https://github.com/zhlooking/react-ssr-redux/pull/4',
#     'diff_url': 'https://github.com/zhlooking/react-ssr-redux/pull/4.diff',
#     'patch_url': 'https://github.com/zhlooking/react-ssr-redux/pull/4.patch',
#     'issue_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/4',
#     'number': 4,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump lodash from 4.17.5 to 4.17.15',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [lodash](https://github.com/lodash/lodash) from 4.17.5 to 4.17.15.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/lodash/lodash/commit/ddfd9b11a0126db2302cb70ec9973b66baec0975"><code>ddfd9b1</code></a> Bump to v4.17.15.</li>\n<li><a href="https://github.com/lodash/lodash/commit/b185fcee26b2133bd071f4aaca14b455c2ed1008"><code>b185fce</code></a> Rebuild lodash and docs.</li>\n<li><a href="https://github.com/lodash/lodash/commit/be87d303941222b97c482755afc0f4a77ce46c30"><code>be87d30</code></a> Bump to v4.17.14.</li>\n<li><a href="https://github.com/lodash/lodash/commit/a6fe6b1e174fd02b5e60eb2664405f4c1262c300"><code>a6fe6b1</code></a> Rebuild lodash and docs.</li>\n<li><a href="https://github.com/lodash/lodash/commit/e37182845f16715a0d1c391c8662d83c55609cee"><code>e371828</code></a> Bump to v4.17.13.</li>\n<li><a href="https://github.com/lodash/lodash/commit/357e899e685872b4af5403ecc4b2a928f961ae63"><code>357e899</code></a> Rebuild lodash and docs.</li>\n<li><a href="https://github.com/lodash/lodash/commit/fd9a062d57646450b61f74029315abd4cc834b08"><code>fd9a062</code></a> Bump to v4.17.12.</li>\n<li><a href="https://github.com/lodash/lodash/commit/e77d68121ff00ba86b53eed5893d35adfe94c9dd"><code>e77d681</code></a> Rebuild lodash and docs.</li>\n<li><a href="https://github.com/lodash/lodash/commit/629d1865793182cd967196716f4beff223aa4a91"><code>629d186</code></a> Update OpenJS references.</li>\n<li><a href="https://github.com/lodash/lodash/commit/2406eac542b2a1282be8d812a6d8a45433ade80a"><code>2406eac</code></a> Fix minified build.</li>\n<li>Additional commits viewable in <a href="https://github.com/lodash/lodash/compare/4.17.5...4.17.15">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=lodash&package-manager=npm_and_yarn&previous-version=4.17.5&new-version=4.17.15)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PR ...
#     'created_at': '2020-06-27T12:07:40Z',
#     'updated_at': '2020-06-27T12:07:40Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/4/commits',
#     'review_comments_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/4/comments',
#     'review_comment_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/4/comments',
#     'statuses_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/statuses/4319e7e506d55556e9733fb18359a1330a6ffa0c',
#     'head': {'label': 'zhlooking:dependabot/npm_and_yarn/lodash-4.17.15',
#      'ref': 'dependabot/npm_and_yarn/lodash-4.17.15',
#      'sha': '4319e7e506d55556e9733fb18359a1330a6ffa0c',
#      'user': {'login': 'zhlooking',
#       'id': 5212377,
#       'node_id': 'MDQ6VXNlcjUyMTIzNzc=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/5212377?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zhlooking',
#       'html_url': 'https://github.com/zhlooking',
#       'followers_url': 'https://api.github.com/users/zhlooking/followers',
#       'following_url': 'https://api.github.com/users/zhlooking/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zhlooking/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zhlooking/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zhlooking/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zhlooking/orgs',
#       'repos_url': 'https://api.github.com/users/zhlooking/repos',
#       'events_url': 'https://api.github.com/users/zhlooking/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zhlooking/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 126305625,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjYzMDU2MjU=',
#       'name': 'react-ssr-redux',
#       'full_name': 'zhlooking/react-ssr-redux',
#       'private': False,
#       'owner': {'login': 'zhlooking',
#        'id': 5212377,
#        'node_id': 'MDQ6VXNlcjUyMTIzNzc=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/5212377?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/zhlooking',
#        'html_url': 'https://github.com/zhlooking',
#        'followers_url': 'https://api.github.com/users/zhlooking/followers',
#        'following_url': 'https://api.github.com/users/zhlooking/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/zhlooking/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/zhlooking/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/zhlooking/subscriptions',
#        'organizations_url': 'https://api.github.com/users/zhlooking/orgs',
#        'repos_url': 'https://api.github.com/users/zhlooking/repos',
#        'events_url': 'https://api.github.com/users/zhlooking/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/zhlooking/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/zhlooking/react-ssr-redux',
#       'description': 'react server side rendering with redux',
#       'fork': False,
#       'url': 'https://api.github.com/repos/zhlooking/react-ssr-redux',
#       'forks_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/forks',
#       'keys_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/teams',
#       'hooks_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/hooks',
#       'issue_events_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/events',
#       'assignees_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/tags',
#       'blobs_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/languages',
#       'stargazers_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/stargazers',
#       'contributors_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/contributors',
#       'subscribers_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/subscribers',
#       'subscription_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/subscription',
#       'commits_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/merges',
#       'archive_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/downloads',
#       'issues_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/deployments',
#       'created_at': '2018-03-22T08:44:00Z',
#       'updated_at': '2018-04-10T04:00:52Z',
#       'pushed_at': '2020-06-27T12:07:40Z',
#       'git_url': 'git://github.com/zhlooking/react-ssr-redux.git',
#       'ssh_url': 'git@github.com:zhlooking/react-ssr-redux.git',
#       'clone_url': 'https://github.com/zhlooking/react-ssr-redux.git',
#       'svn_url': 'https://github.com/zhlooking/react-ssr-redux',
#       'homepage': None,
#       'size': 253,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'zhlooking:master',
#      'ref': 'master',
#      'sha': '05449bea3d273d36ea333818f1550c35ab3c5f2d',
#      'user': {'login': 'zhlooking',
#       'id': 5212377,
#       'node_id': 'MDQ6VXNlcjUyMTIzNzc=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/5212377?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zhlooking',
#       'html_url': 'https://github.com/zhlooking',
#       'followers_url': 'https://api.github.com/users/zhlooking/followers',
#       'following_url': 'https://api.github.com/users/zhlooking/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zhlooking/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zhlooking/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zhlooking/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zhlooking/orgs',
#       'repos_url': 'https://api.github.com/users/zhlooking/repos',
#       'events_url': 'https://api.github.com/users/zhlooking/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zhlooking/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 126305625,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMjYzMDU2MjU=',
#       'name': 'react-ssr-redux',
#       'full_name': 'zhlooking/react-ssr-redux',
#       'private': False,
#       'owner': {'login': 'zhlooking',
#        'id': 5212377,
#        'node_id': 'MDQ6VXNlcjUyMTIzNzc=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/5212377?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/zhlooking',
#        'html_url': 'https://github.com/zhlooking',
#        'followers_url': 'https://api.github.com/users/zhlooking/followers',
#        'following_url': 'https://api.github.com/users/zhlooking/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/zhlooking/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/zhlooking/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/zhlooking/subscriptions',
#        'organizations_url': 'https://api.github.com/users/zhlooking/orgs',
#        'repos_url': 'https://api.github.com/users/zhlooking/repos',
#        'events_url': 'https://api.github.com/users/zhlooking/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/zhlooking/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/zhlooking/react-ssr-redux',
#       'description': 'react server side rendering with redux',
#       'fork': False,
#       'url': 'https://api.github.com/repos/zhlooking/react-ssr-redux',
#       'forks_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/forks',
#       'keys_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/teams',
#       'hooks_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/hooks',
#       'issue_events_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/events',
#       'assignees_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/tags',
#       'blobs_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/languages',
#       'stargazers_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/stargazers',
#       'contributors_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/contributors',
#       'subscribers_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/subscribers',
#       'subscription_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/subscription',
#       'commits_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/merges',
#       'archive_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/downloads',
#       'issues_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/zhlooking/react-ssr-redux/deployments',
#       'created_at': '2018-03-22T08:44:00Z',
#       'updated_at': '2018-04-10T04:00:52Z',
#       'pushed_at': '2020-06-27T12:07:40Z',
#       'git_url': 'git://github.com/zhlooking/react-ssr-redux.git',
#       'ssh_url': 'git@github.com:zhlooking/react-ssr-redux.git',
#       'clone_url': 'https://github.com/zhlooking/react-ssr-redux.git',
#       'svn_url': 'https://github.com/zhlooking/react-ssr-redux',
#       'homepage': None,
#       'size': 253,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/4'},
#      'html': {'href': 'https://github.com/zhlooking/react-ssr-redux/pull/4'},
#      'issue': {'href': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/4'},
#      'comments': {'href': 'https://api.github.com/repos/zhlooking/react-ssr-redux/issues/4/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/4/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/zhlooking/react-ssr-redux/pulls/4/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/zhlooking/react-ssr-redux/statuses/4319e7e506d55556e9733fb18359a1330a6ffa0c'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 4,
#     'deletions': 4,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-06-27T12:07:41Z'},
#  {'id': '12751628753',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1247192,
#    'login': 'pholthau',
#    'display_login': 'pholthau',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pholthau',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1247192?'},
#   'repo': {'id': 60243197,
#    'name': 'nextcloud/server',
#    'url': 'https://api.github.com/repos/nextcloud/server'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/nextcloud/server/issues/21429',
#     'repository_url': 'https://api.github.com/repos/nextcloud/server',
#     'labels_url': 'https://api.github.com/repos/nextcloud/server/issues/21429/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/nextcloud/server/issues/21429/comments',
#     'events_url': 'https://api.github.com/repos/nextcloud/server/issues/21429/events',
#     'html_url': 'https://github.com/nextcloud/server/issues/21429',
#     'id': 639531851,
#     'node_id': 'MDU6SXNzdWU2Mzk1MzE4NTE=',
#     'number': 21429,
#     'title': 'No access to external storage.',
#     'user': {'login': 'Bables55',
#      'id': 30524004,
#      'node_id': 'MDQ6VXNlcjMwNTI0MDA0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/30524004?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Bables55',
#      'html_url': 'https://github.com/Bables55',
#      'followers_url': 'https://api.github.com/users/Bables55/followers',
#      'following_url': 'https://api.github.com/users/Bables55/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Bables55/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Bables55/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Bables55/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Bables55/orgs',
#      'repos_url': 'https://api.github.com/users/Bables55/repos',
#      'events_url': 'https://api.github.com/users/Bables55/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Bables55/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 393047742,
#       'node_id': 'MDU6TGFiZWwzOTMwNDc3NDI=',
#       'url': 'https://api.github.com/repos/nextcloud/server/labels/0.%20Needs%20triage',
#       'name': '0. Needs triage',
#       'color': '0052cc',
#       'default': False,
#       'description': 'Pending check for reproducibility or if it fits our roadmap'},
#      {'id': 386379231,
#       'node_id': 'MDU6TGFiZWwzODYzNzkyMzE=',
#       'url': 'https://api.github.com/repos/nextcloud/server/labels/bug',
#       'name': 'bug',
#       'color': 'ee0701',
#       'default': True,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2020-06-16T09:54:28Z',
#     'updated_at': '2020-06-27T12:07:40Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
# ...
#      'subscriptions_url': 'https://api.github.com/users/youngkin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/youngkin/orgs',
#      'repos_url': 'https://api.github.com/users/youngkin/repos',
#      'events_url': 'https://api.github.com/users/youngkin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/youngkin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-07T17:29:37Z',
#     'updated_at': '2020-06-27T12:07:40Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '<!--- Provide a general summary of the issue in the Title above -->\r\nIn GUIDE.md, in the "Start up the Kubernetes dashboard" section, the `kubectl apply ...` command is referencing a resource that no longer exists. Here\'s the `kubectl apply ...` command from the guide along with the response:\r\n\r\n```\r\n$ kubectl apply -f https://raw.githubusercontent.com/kubernetes/dashboard/master/aio/deploy/alternative/kubernetes-dashboard-arm-head.yaml\r\nerror: unable to read URL "https://raw.githubusercontent.com/kubernetes/dashboard/master/aio/deploy/alternative/kubernetes-dashboard-arm-head.yaml", server reported 404 Not Found, status code=404\r\n```\r\n\r\nI poked around in the Kubernetes Dashboard repo and it appears that an ARM version is no longer available. I did find some deployment specs referencing older versions of the ARM dashboard image, but those images use the now retired Kubernetes Hipster instead of the Kubernetes Metrics Server. The dashboard  pod log shows:\r\n`2020/03/07 17:00:00 Metric client health check failed: the server could not find the requested resource (get services heapster). Retrying in 30 seconds.`\r\n\r\n## Expected Behaviour\r\nI expected that the `kubectl apply ...` would successfully download the deployment spec and create the required resources.\r\n\r\n## Current Behaviour\r\nSee above, the `kubectl apply ...` returns a 404 not found\r\n\r\n## Possible Solution\r\nFind a current arm version of the Kubernetes Dashboard.\r\n\r\n## Steps to Reproduce (for bugs)\r\n\r\n1. Run the `kubectl apply ...` command referenced in GUIDE.md, i.e., \r\n```\r\nkubectl apply -f https://raw.githubusercontent.com/kubernetes/dashboard/master/aio/deploy/alternative/kubernetes-dashboard-arm-head.yaml\r\n```\r\n\r\n\r\n## Context\r\nI was hoping to install the dashboard to visually inspect my cluster.\r\n\r\n## Your Environment\r\n\r\n* Docker version `docker version` (e.g. Docker 17.0.05 ): \r\n```\r\n$ d version\r\nClient: Docker Engine - Community\r\n Version:           19.03.5\r\n API version:       1.40\r\n Go version:        go1.12.12\r\n Git commit:        633a0ea\r\n Built:             Wed Nov 13 07:22:34 2019\r\n OS/Arch:           darwin/amd64\r\n Experimental:      false\r\n\r\nServer: Docker Engine - Community\r\n Engine:\r\n  Version:          19.03.5\r\n  API version:      1.40 (minimum version 1.12)\r\n  Go version:       go1.12.12\r\n  Git commit:       633a0ea\r\n  Built:            Wed Nov 13 07:29:19 2019\r\n  OS/Arch:          linux/amd64\r\n  Experimental:     false\r\n containerd:\r\n  Version:          v1.2.10\r\n  GitCommit:        b34a5c8af56e510852c35414db4c1f4fa6172339\r\n runc:\r\n  Version:          1.0.0-rc8+dev\r\n  GitCommit:        3e425f80a8c931f88e6d94a8c831b9d5aa481657\r\n docker-init:\r\n  Version:          0.18.0\r\n  GitCommit:        fec3683\r\n```\r\n\r\n* What version of Kubernetes are you using? `kubectl version`:\r\n```\r\nk version\r\nClient Version: version.Info{Major:"1", Minor:"17", GitVersion:"v1.17.3", GitCommit:"06ad960bfd03b39c8310aaf92d1e7c12ce618213", GitTreeState:"clean", BuildDate:"2020-02-13T18:08:14Z", GoVersion:"go1.13.8", Compiler:"gc", Platform:"darwin/amd64"}\r\nServer Version: version.Info{Major:"1", Minor:"15", GitVersion:"v1.15.3", GitCommit:"2d3c76f9091b6bec110a5e63777c332469e0cba2", GitTreeState:"clean", BuildDate:"2019-08-19T11:05:50Z", GoVersion:"go1.12.9", Compiler:"gc", Platform:"linux/arm"}\r\n```\r\n\r\n* Operating System and version (e.g. Linux, Windows, MacOS):\r\nThe client is a Mac\r\n\r\n* What ARM or Raspberry Pi board are you using?\r\nPi 4B\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/teamserverless/k8s-on-raspbian/issues/comments/650552068',
#     'html_url': 'https://github.com/teamserverless/k8s-on-raspbian/issues/26#issuecomment-650552068',
#     'issue_url': 'https://api.github.com/repos/teamserverless/k8s-on-raspbian/issues/26',
#     'id': 650552068,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY1MDU1MjA2OA==',
#     'user': {'login': 'davelosert',
#      'id': 4287128,
#      'node_id': 'MDQ6VXNlcjQyODcxMjg=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/4287128?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/davelosert',
#      'html_url': 'https://github.com/davelosert',
#      'followers_url': 'https://api.github.com/users/davelosert/followers',
#      'following_url': 'https://api.github.com/users/davelosert/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/davelosert/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/davelosert/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/davelosert/subscriptions',
#      'organizations_url': 'https://api.github.com/users/davelosert/orgs',
#      'repos_url': 'https://api.github.com/users/davelosert/repos',
#      'events_url': 'https://api.github.com/users/davelosert/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/davelosert/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-06-27T12:07:40Z',
#     'updated_at': '2020-06-27T12:07:40Z',
#     'author_association': 'NONE',
#     'body': 'I also just stumbled upon this.\r\n\r\nHowever, there is already an PR that fixes the URL: #30\r\nThe ClusterDashboard still natively supports ARM.\r\n\r\nHowever, I had to use another `ClusterRoleBinding` to make it work:\r\n\r\n```\r\napiVersion: rbac.authorization.k8s.io/v1beta1\r\nkind: ClusterRoleBinding\r\nmetadata:\r\n  name: kubernetes-dashboard-admin\r\n  labels:\r\n    k8s-app: kubernetes-dashboard\r\nroleRef:\r\n  apiGroup: rbac.authorization.k8s.io\r\n  kind: ClusterRole\r\n  name: cluster-admin\r\nsubjects:\r\n- kind: ServiceAccount\r\n  name: kubernetes-dashboard\r\n  namespace: kubernetes-dashboard\r\n``` '}},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z',
#   'org': {'id': 49474643,
#    'login': 'teamserverless',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/teamserverless',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49474643?'}},
#  {'id': '12751628726',
#   'type': 'PushEvent',
#   'actor': {'id': 58334128,
#    'login': 'otiny',
#    'display_login': 'otiny',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/otiny',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58334128?'},
#   'repo': {'id': 224857031,
#    'name': 'otiny/up',
#    'url': 'https://api.github.com/repos/otiny/up'},
#   'payload': {'push_id': 5292949341,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '28718bf90e0e4876a4ae074e62cb370c151526cd',
#    'before': 'e2de20607cb0ee62d918bc03b0dbd9dcc2940415',
#    'commits': [{'sha': '28718bf90e0e4876a4ae074e62cb370c151526cd',
#      'author': {'email': '58334128+otiny@users.noreply.github.com',
#       'name': 'otiny'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/otiny/up/commits/28718bf90e0e4876a4ae074e62cb370c151526cd'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z'},
#  {'id': '12751628733',
#   'type': 'IssuesEvent',
#   'actor': {'id': 28506941,
#    'login': 'oddjob201',
#    'display_login': 'oddjob201',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/oddjob201',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28506941?'},
#   'repo': {'id': 271831771,
#    'name': 'oddjob201/markdown-practice-portfolio',
#    'url': 'https://api.github.com/repos/oddjob201/markdown-practice-portfolio'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/oddjob201/markdown-practice-portfolio/issues/4',
#     'repository_url': 'https://api.github.com/repos/oddjob201/markdown-practice-portfolio',
#     'labels_url': 'https://api.github.com/repos/oddjob201/markdown-practice-portfolio/issues/4/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/oddjob201/markdown-practice-portfolio/issues/4/comments',
#     'events_url': 'https://api.github.com/repos/oddjob201/markdown-practice-portfolio/issues/4/events',
#     'html_url': 'https://github.com/oddjob201/markdown-practice-portfolio/issues/4',
#     'id': 646669144,
#     'node_id': 'MDU6SXNzdWU2NDY2NjkxNDQ=',
#     'number': 4,
#     'title': '## Step 6: Add a profile link',
#     'user': {'login': 'oddjob201',
#      'id': 28506941,
#      'node_id': 'MDQ6VXNlcjI4NTA2OTQx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/28506941?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/oddjob201',
#      'html_url': 'https://github.com/oddjob201',
#      'followers_url': 'https://api.github.com/users/oddjob201/followers',
#      'following_url': 'https://api.github.com/users/oddjob201/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/oddjob201/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/oddjob201/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/oddjob201/subscriptions',
#      'organizations_url': 'https://api.github.com/users/oddjob201/orgs',
#      'repos_url': 'https://api.github.com/users/oddjob201/repos',
#      'events_url': 'https://api.github.com/users/oddjob201/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/oddjob201/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-06-27T12:07:40Z',
#     'updated_at': '2020-06-27T12:07:40Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': '## Step 6: Add a profile link\r\n\r\nYour image looks great! Next, you\'ll want to add links to your awesome portfolio projects. Links help create context when you’re communicating in issues and pull requests.\r\n\r\nYou might link to a [website](https://github.com/), a [repository](https://github.com/github/training-kit), or even a [line of code](https://github.com/github/training-kit/blob/master/resources/learning-path/index.html#L32). To create a link, put the text you want to display in square brackets, and the URL in the following parentheses.\r\n\r\n```\r\n[GitHub](http://github.com)\r\n```\r\n\r\n## :keyboard: Activity: Add a link\r\n\r\n\r\n1. Edit the file `_includes/03-links.md`.\r\n1. Replace the filler text with a link to your GitHub profile (or anywhere else).\r\n\r\n\r\n<hr>\r\n<h3 align="center">Watch below for my response!</h3>\r\n\r\n_Originally posted by @github-learning-lab in https://github.com/oddjob201/markdown-practice-portfolio/pull/3#issuecomment-643782703_'}},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z'},
#  {'id': '12751628727',
#   'type': 'PushEvent',
#   'actor': {'id': 15820133,
#    'login': 'MartinEmbers',
#    'display_login': 'MartinEmbers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MartinEmbers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15820133?'},
#   'repo': {'id': 259275129,
#    'name': 'ea-contrib/tizen-movie-app',
#    'url': 'https://api.github.com/repos/ea-contrib/tizen-movie-app'},
#   'payload': {'push_id': 5292949346,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': '6da995e56ffd0808d148090682e752ed3def4862',
#    'before': 'e4de106d8e6da5d66d8c47a43c6990163ebc65ae',
#    'commits': [{'sha': '6da995e56ffd0808d148090682e752ed3def4862',
#      'author': {'email': 'EKhudik@qulix.com', 'name': 'khudikea'},
#      'message': 'Movie service added\ndevops fixes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ea-contrib/tizen-movie-app/commits/6da995e56ffd0808d148090682e752ed3def4862'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z',
#   'org': {'id': 59224854,
#    'login': 'ea-contrib',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ea-contrib',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59224854?'}},
#  {'id': '12751628724',
#   'type': 'PushEvent',
#   'actor': {'id': 34999007,
#    'login': 'ua1arn',
#    'display_login': 'ua1arn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ua1arn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34999007?'},
#   'repo': {'id': 162910729,
#    'name': 'ua1arn/hftrx',
#    'url': 'https://api.github.com/repos/ua1arn/hftrx'},
#   'payload': {'push_id': 5292949350,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/STM32MP1_SMP_tests',
#    'head': '672f58369a1cec0fbd9fa6361a63b8e138d640c7',
#    'before': 'c6416626cce2cdcba110c616d6c45c2240f0f703',
#    'commits': [{'sha': '672f58369a1cec0fbd9fa6361a63b8e138d640c7',
#      'author': {'email': 'mgs2001@mail.ru', 'name': 'ua1arn'},
#      'message': 'STM32MP1: style',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ua1arn/hftrx/commits/672f58369a1cec0fbd9fa6361a63b8e138d640c7'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z'},
#  {'id': '12751628725',
#   'type': 'PushEvent',
#   'actor': {'id': 61640292,
#    'login': 'XT-0220',
#    'display_login': 'XT-0220',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/XT-0220',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61640292?'},
#   'repo': {'id': 275362013,
#    'name': 'XT-0220/DjangoBase',
#    'url': 'https://api.github.com/repos/XT-0220/DjangoBase'},
#   'payload': {'push_id': 5292949348,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '511c1d5fcfa390da0088ff1b8a7a3062ab7a6eef',
#    'before': '129cd0183ad17250898568bc8a0b87130b0f6d96',
#    'commits': [{'sha': '511c1d5fcfa390da0088ff1b8a7a3062ab7a6eef',
#      'author': {'email': '1606778306@qq.com', 'name': 'J_XT'},
#      'message': '注册',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/XT-0220/DjangoBase/commits/511c1d5fcfa390da0088ff1b8a7a3062ab7a6eef'}]},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z'},
#  {'id': '12751628717',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 126305625,
#    'name': 'zhlooking/react-ssr-redux',
#    'url': 'https://api.github.com/repos/zhlooking/react-ssr-redux'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/lodash-es-4.17.15',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'react server side rendering with redux',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z'},
#  {'id': '12751628718',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 126305625,
#    'name': 'zhlooking/react-ssr-redux',
#    'url': 'https://api.github.com/repos/zhlooking/react-ssr-redux'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/lodash-4.17.15',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'react server side rendering with redux',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-27T12:07:40Z'}]

# %%
type(json.loads(r.text))
# Out:
# list

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
#API接口練習 - 即時水位資料
import requests

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
json.loads(r.text) #資料透過 json.loads 將 json 字串轉換為 dict
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2200H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.15},
#   {'StationIdentifier': '1730H070',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 226.25},
#   {'StationIdentifier': '1580H021',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.28},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 25.73},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.48},
#   {'StationIdentifier': '1580H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 224.21},
#   {'StationIdentifier': '1730H075',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 92.83},
#   {'StationIdentifier': '2420H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 164.37},
#   {'StationIdentifier': '2500H003',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.2},
#   {'StationIdentifier': '1730H066',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 138.73},
#   {'StationIdentifier': '1730H077',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 740.49},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 26.75},
#   {'StationIdentifier': '1670H004',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 2.98},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 109.97},
#   {'StationIdentifier': '1650H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.7},
#   {'StationIdentifier': '1730H061',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 266.23},
#   {'StationIdentifier': '1730H072',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 248.86},
#   {'StationIdentifier': '1540H039',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 38.99},
#   {'StationIdentifier': '1660H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.14},
#   {'StationIdentifier': '2370H025',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 261.61},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.1},
#   {'StationIdentifier': '1730H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 43.48},
#   {'StationIdentifier': '1730H068',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.14},
#   {'StationIdentifier': '1540H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.01},
#   {'StationIdentifier': '1650H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.05},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 124.1},
#   {'StationIdentifier': '1630H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 65.83},
#   {'StationIdentifier': '1660H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.85},
#   {'StationIdentifier': '1730H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.04},
#   {'StationIdentifier': '2420H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.32},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.4},
#   {'StationIdentifier': '1650H010',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.19},
#   {'StationIdentifier': '1630H030',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 1.57},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 0.13},
#   {'StationIdentifier': '1650H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 5.62},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.11},
#   {'StationIdentifier': '2200H026',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 106.73},
#   {'StationIdentifier': '1350H031',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -0.15},
#   {'StationIdentifier': '1630H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.76},
#   {'StationIdentifier': '1630H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.01},
#   {'StationIdentifier': '1630H027',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 26.14},
#   {'StationIdentifier': '1540H032',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.45},
#   {'StationIdentifier': '1550H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.54},
#   {'StationIdentifier': '1630H023',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.03},
#   {'StationIdentifier': '1350H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 175.97},
#   {'StationIdentifier': '1630H034',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 278.47},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 11.27},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 69.07},
#   {'StationIdentifier': '1540H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 13.13},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 27.2},
#   {'StationIdentifier': '1630H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 39.76},
#   {'StationIdentifier': '1350H027',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.89},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 752.39},
#   {'StationIdentifier': '1580H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.16},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 48.29},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.06},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.59},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.76},
#   {'StationIdentifier': '1510H080',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1068.94},
#   {'StationIdentifier': '1510H058',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 12.13},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 380.46},
#   {'StationIdentifier': '1430H051',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 95.66},
#   {'StationIdentifier': '1350H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 259.67},
#   {'StationIdentifier': '1520H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 78.22},
#   {'StationIdentifier': '1580H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 21.23},
#   {'StationIdentifier': '1510H079',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 187.7},
#   {'StationIdentifier': '1510H049',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 470.82},
#   {'StationIdentifier': '1430H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.6},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 72.35},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 220.79},
#   {'StationIdentifier': '1510H086',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 317.97},
#   {'StationIdentifier': '1580H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.39},
#   {'StationIdentifier': '1510H071',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 20.5},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.83},
#   {'StationIdentifier': '1420H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 639.41},
#   {'StationIdentifier': '1420H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 440.47},
#   {'StationIdentifier': '1350H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 97.9},
#   {'StationIdentifier': '1550H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 15.74},
#   {'StationIdentifier': '1510H075',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 346.5},
#   {'StationIdentifier': '1430H045',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 91.76},
#   {'StationIdentifier': '1430H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 83.01},
#   {'StationIdentifier': '1400H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 622.43},
#   {'StationIdentifier': '1420H055',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 318.68},
#   {'StationIdentifier': '1340H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.08},
#   {'StationIdentifier': '1420H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 704.2},
#   {'StationIdentifier': '1350H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 282.05},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.29},
#   {'StationIdentifier': '1340H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.37},
#   {'StationIdentifier': '1400H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 191.55},
#   {'StationIdentifier': '1140H106',
#    'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'WaterLevel': 49.11},
#   {'StationIdentifier': '2370H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 58.49},
#   {'StationIdentifier': '1420H049',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 54.19},
#   {'StationIdentifier': '1350H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 169.81},
#   {'StationIdentifier': '1300H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -1.01},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 7.38},
#   {'StationIdentifier': '1140H108',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 12.12},
#   {'StationIdentifier': '1140H099',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 263.49},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 22.09},
#   {'StationIdentifier': '1400H019',
#    'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'WaterLevel': 310.14},
#   {'StationIdentifier': '1290H002',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}

# %%
#觀察資料
j = json.loads(r.text)
print(len(j)) #此list含有四組內容，包括@odata.context、@odata.count, value, @odata.nextLink。其中大多數資料儲存於value中
print(len(j['value'])) #此list含有100組資料，每一組資料都含有RecordTime, StationIdentifier, WaterLevel的資訊
# Out:
# 4
# 100

# %%
# 用迴圈存取每一個測站所記錄的時間水位高度
j = json.loads(r.text)
for i in range(len(j['value'])): 
    print (j['value'][i]['RecordTime'], #記錄的時間
           j['value'][i]['StationIdentifier'], #測站序號
           j['value'][i]['WaterLevel']) #水位高度
# Out:
# Dec 11, 2019 2:50:00 PM 2200H029 145.15
# Dec 11, 2019 2:50:00 PM 1730H070 226.25
# Dec 11, 2019 2:50:00 PM 1580H021 1.28
# Dec 11, 2019 2:50:00 PM 1580H017 25.73
# Dec 11, 2019 2:50:00 PM 2560H019 4.48
# Dec 11, 2019 2:50:00 PM 1580H001 224.21
# Dec 11, 2019 2:50:00 PM 1730H075 92.83
# Dec 11, 2019 2:50:00 PM 2420H036 164.37
# Dec 11, 2019 2:50:00 PM 2500H003 32.2
# Dec 11, 2019 2:50:00 PM 1730H066 138.73
# Dec 11, 2019 2:50:00 PM 1730H077 740.49
# Dec 11, 2019 2:50:00 PM 1550H014 26.75
# Dec 11, 2019 2:50:00 PM 1670H004 2.98
# Dec 11, 2019 2:50:00 PM 2420H019 109.97
# Dec 11, 2019 2:50:00 PM 1650H012 0.7
# Dec 11, 2019 2:50:00 PM 1730H061 266.23
# Dec 11, 2019 2:50:00 PM 1730H072 248.86
# Dec 11, 2019 2:50:00 PM 1540H039 38.99
# Dec 11, 2019 2:50:00 PM 1660H012 0.14
# Dec 11, 2019 2:50:00 PM 2370H025 261.61
# Dec 11, 2019 2:50:00 PM 1650H009 0.1
# Dec 11, 2019 2:50:00 PM 1730H057 43.48
# Dec 11, 2019 2:50:00 PM 1730H068 10.14
# Dec 11, 2019 2:50:00 PM 1540H037 32.01
# Dec 11, 2019 2:50:00 PM 1650H015 0.05
# Dec 11, 2019 2:50:00 PM 2370H018 124.1
# Dec 11, 2019 2:50:00 PM 1630H036 65.83
# Dec 11, 2019 2:50:00 PM 1660H009 4.85
# Dec 11, 2019 2:50:00 PM 1730H043 23.04
# Dec 11, 2019 2:50:00 PM 2420H043 79.32
# Dec 11, 2019 2:50:00 PM 1540H033 23.4
# Dec 11, 2019 2:50:00 PM 1650H010 0.19
# Dec 11, 2019 2:20:00 PM 1630H030 1.57
# Dec 11, 2019 2:20:00 PM 1630H032 0.13
# Dec 11, 2019 2:50:00 PM 1650H013 5.62
# Dec 11, 2019 2:50:00 PM 1680H005 0.11
# Dec 11, 2019 2:50:00 PM 2200H026 106.73
# Dec 11, 2019 2:50:00 PM 1350H031 -0.15
# Dec 11, 2019 2:50:00 PM 1630H040 1.76
# Dec 11, 2019 2:50:00 PM 1630H018 10.01
# Dec 11, 2019 2:20:00 PM 1630H027 26.14
# Dec 11, 2019 2:50:00 PM 1540H032 20.45
# Dec 11, 2019 2:50:00 PM 1550H012 0.54
# Dec 11, 2019 2:50:00 PM 1630H023 0.03
# Dec 11, 2019 2:50:00 PM 1350H029 175.97
# Dec 11, 2019 2:20:00 PM 1630H034 278.47
# Dec 11, 2019 2:50:00 PM 1590H016 11.27
# Dec 11, 2019 2:50:00 PM 1630H024 69.07
# Dec 11, 2019 2:50:00 PM 1540H029 13.13
# Dec 11, 2019 2:50:00 PM 1540H030 27.2
# Dec 11, 2019 2:50:00 PM 1630H005 39.76
# Dec 11, 2019 2:50:00 PM 1350H027 145.89
# Dec 11, 2019 2:50:00 PM 1510H082 752.39
# Dec 11, 2019 2:50:00 PM 1580H022 0.16
# Dec 11, 2019 2:50:00 PM 1430H054 48.29
# Dec 11, 2019 2:50:00 PM 1510H084 145.06
# Dec 11, 2019 2:50:00 PM 1540H009 0.59
# Dec 11, 2019 2:50:00 PM 1590H013 20.76
# Dec 11, 2019 2:50:00 PM 1510H080 1068.94
# Dec 11, 2019 9:50:00 AM 1510H058 12.13
# Dec 11, 2019 2:50:00 PM 1430H037 380.46
# Dec 11, 2019 2:50:00 PM 1430H051 95.66
# Dec 11, 2019 2:50:00 PM 1350H024 259.67
# Dec 11, 2019 2:50:00 PM 1520H008 78.22
# Dec 11, 2019 2:50:00 PM 1580H018 21.23
# Dec 11, 2019 9:50:00 AM 1510H079 187.7
# Dec 11, 2019 9:50:00 AM 1510H049 470.82
# Dec 11, 2019 2:50:00 PM 1430H029 50.6
# Dec 11, 2019 2:50:00 PM 1430H047 72.35
# Dec 11, 2019 2:50:00 PM 1350H020 220.79
# Dec 11, 2019 2:50:00 PM 1510H086 317.97
# Dec 11, 2019 2:50:00 PM 1580H008 19.39
# Dec 11, 2019 9:50:00 AM 1510H071 20.5
# Dec 11, 2019 2:50:00 PM 1430H056 79.83
# Dec 11, 2019 2:50:00 PM 1420H057 639.41
# Dec 11, 2019 2:50:00 PM 1420H058 440.47
# Dec 11, 2019 2:50:00 PM 1350H016 97.9
# Dec 11, 2019 2:50:00 PM 1550H017 15.74
# Dec 11, 2019 9:50:00 AM 1510H075 346.5
# Dec 11, 2019 2:50:00 PM 1430H045 91.76
# Dec 11, 2019 2:50:00 PM 1430H058 83.01
# Dec 11, 2019 2:50:00 PM 1400H015 622.43
# Dec 11, 2019 2:50:00 PM 1420H055 318.68
# Dec 11, 2019 2:50:00 PM 1340H015 50.08
# Dec 11, 2019 2:50:00 PM 1420H054 704.2
# Dec 11, 2019 2:50:00 PM 1350H018 282.05
# Dec 11, 2019 2:50:00 PM 1430H040 19.29
# Dec 11, 2019 2:50:00 PM 1340H014 0.37
# Dec 11, 2019 2:50:00 PM 1400H009 191.55
# Dec 11, 2019 2:55:00 PM 1140H106 49.11
# Dec 11, 2019 2:50:00 PM 2370H017 58.49
# Dec 11, 2019 2:50:00 PM 1420H049 54.19
# Dec 11, 2019 2:50:00 PM 1350H001 169.81
# Dec 11, 2019 2:50:00 PM 1300H022 -1.01
# Dec 11, 2019 2:50:00 PM 1340H011 7.38
# Dec 11, 2019 2:50:00 PM 1140H108 12.12
# Dec 11, 2019 2:50:00 PM 1140H099 263.49
# Dec 11, 2019 2:50:00 PM 1850H005 22.09
# Dec 11, 2019 2:40:00 PM 1400H019 310.14
# Dec 11, 2019 2:50:00 PM 1290H002 41

# %% [markdown]
# ## 備註 - json概念
# * 參考資料: https://dotblogs.com.tw/kevinya/2018/09/09/

# %%
#剖析json
import json
j = json.loads(
    '{"one" : "1", "two" : "2", "three" : "3","twoDimension" : {"lv2id":"777", "lv2name":"superman"}}')
print(j['two'])
print(j['twoDimension']["lv2id"])
# Out:
# 2
# 777
